# %%
from pathlib import Path
import sys

# from sklearn.cluster import k_means
path_root = Path(__file__).parents[2]
sys.path.append(str(path_root))
print(sys.path)

import swordcloud as swc

# import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('swordcloud/example/w_review_data.csv', names=['text'])
txt = list(df['text'][0:4000])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/pf/tmc160h92v12grcjm5v91jqm0000gp/T/ipykernel_81298/1046688327.py in <module>
#       3
#       4 # from sklearn.cluster import k_means
# ----> 5 path_root = Path(__file__).parents[2]
#       6 sys.path.append(str(path_root))
#       7 print(sys.path)
#
# NameError: name '__file__' is not defined

# %%
wn_wc = swc.WordCloud(background_color='white',
                     width=3360,
                     height=1890,
                     colormap='tab10',
                     max_font_size=400,
                     color_func=lambda *args, **kwargs: "black",
                     prefer_horizontal=1.0,
                     language='TH')

wn_wc.generate_from_text(txt)

# %%
# import importlib
# importlib.reload(swc)

wn_wc2 = swc.WordCloud(background_color='white',
                     width=3360,
                     height=1890,
                     colormap='tab10',
                     max_font_size=400,
                     color_func=lambda *args, **kwargs: "black",
                     prefer_horizontal=1.0,
                     language='TH')

wn_wc2.generate_from_text(txt, kmeans=True)
# Out:
# /Users/pzzlng1/swordcloud/swordcloud/wordcloud.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clus_i['total'] = clus_i['word_count'].sum()
# /Users/pzzlng1/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:991: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
# /Users/pzzlng1/swordcloud/swordcloud/query_integral_image.py:56: RuntimeWarning: overflow encountered in uint_scalars
#   area -= integral_image[new_center_x + size_x, new_center_y] + integral_image[new_center_x, new_center_y + size_y]
# generating cloud 0
# /Users/pzzlng1/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:991: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
# /Users/pzzlng1/swordcloud/swordcloud/query_integral_image.py:56: RuntimeWarning: overflow encountered in uint_scalars
#   area -= integral_image[new_center_x + size_x, new_center_y] + integral_image[new_center_x, new_center_y + size_y]
# generating cloud 1
# /Users/pzzlng1/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:991: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
# /Users/pzzlng1/swordcloud/swordcloud/query_integral_image.py:56: RuntimeWarning: overflow encountered in uint_scalars
#   area -= integral_image[new_center_x + size_x, new_center_y] + integral_image[new_center_x, new_center_y + size_y]
# generating cloud 2
# /Users/pzzlng1/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:991: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
# /Users/pzzlng1/swordcloud/swordcloud/query_integral_image.py:56: RuntimeWarning: overflow encountered in uint_scalars
#   area -= integral_image[new_center_x + size_x, new_center_y] + integral_image[new_center_x, new_center_y + size_y]
# generating cloud 3
# /Users/pzzlng1/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:991: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
# /Users/pzzlng1/swordcloud/swordcloud/query_integral_image.py:56: RuntimeWarning: overflow encountered in uint_scalars
#   area -= integral_image[new_center_x + size_x, new_center_y] + integral_image[new_center_x, new_center_y + size_y]
# generating cloud 4
# /Users/pzzlng1/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:991: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
# /Users/pzzlng1/swordcloud/swordcloud/query_integral_image.py:56: RuntimeWarning: overflow encountered in uint_scalars
#   area -= integral_image[new_center_x + size_x, new_center_y] + integral_image[new_center_x, new_center_y + size_y]
# generating cloud 5
